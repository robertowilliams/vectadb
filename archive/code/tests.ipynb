# %%
import weaviate

client = weaviate.connect_to_local(host="localhost", port=8081)
collection = client.collections.get("AgentMetadata")

# %%
mongosh "mongodb://root:007N5GCH6VVWB57U@ep-mongodb.everypeer.mars:6100/shortid_db" \
  --eval 'db.shortids.find({}, {id:1, metadata:1, _id:0}).pretty()'
